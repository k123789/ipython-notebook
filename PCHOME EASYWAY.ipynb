# %%
import requests
from bs4 import BeautifulSoup
import json

# %%
url= "https://ecshweb.pchome.com.tw/search/v3.3/all/results?q=PS4&page=1&sort=rnk/dc"
res=requests.get(url)
data=json.loads(res.text)

# %%
res.text
# Out:
# '{"QTime":47,"totalRows":1526,"totalPage":77,"range":{"min":"","max":""},"cateName":"","q":"PS4","subq":"","token":["PS4","PS","4"],"prods":[{"Id":"DGBJA7-A9008RJA1","cateId":"DGBJA7","picS":"\\/items\\/DGBJA7A9008RJA1\\/000002_1517795410.jpg","picB":"\\/items\\/DGBJA7A9008RJA1\\/000001_1519609686.jpg","name":"PS4 Slim\\u4e3b\\u6a5f 500GB\\u300a\\u6975\\u81f4\\u9ed1\\u300b","describe":"PS4 Slim\\u4e3b\\u6a5f CUH-2117AB01 \\u7cfb\\u5217 500G (\\u6975\\u81f4\\u9ed1)","price":9980,"originPrice":9980,"author":"","brand":"","publishDate":"","sellerId":"","isPChome":1,"isNC17":0,"couponActid":[]},{"Id":"DGBJA7-A9008KXL7","cateId":"DGBJA7","picS":"\\/items\\/DGBJA7A9008KXL7\\/000002_1514635363.jpg","picB":"\\/items\\/DGBJA7A9008KXL7\\/000001_1519609863.jpg","name":"PS4 Pro -1TB (\\u6975\\u81f4\\u9ed1)","describe":"Sony PS4 Pro\\u4e3b\\u6a5f- 1TB (\\u6975\\u81f4\\u9ed1)","price":12980,"originPrice":12980,"author":"","brand":"","publishDate":"","sellerId":"","isPChome":1,"isNC17":0,"couponAct
# ...

# %%
data
# Out:
# {'QTime': 47,
#  'cateName': '',
#  'prods': [{'Id': 'DGBJA7-A9008RJA1',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGBJA7',
#    'couponActid': [],
#    'describe': 'PS4 Slim主機 CUH-2117AB01 系列 500G (極致黑)',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'PS4 Slim主機 500GB《極致黑》',
#    'originPrice': 9980,
#    'picB': '/items/DGBJA7A9008RJA1/000001_1519609686.jpg',
#    'picS': '/items/DGBJA7A9008RJA1/000002_1517795410.jpg',
#    'price': 9980,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGBJA7-A9008KXL7',
#    'author': '',
#    'brand': '',
#    'cateId': 'DGBJA7',
#    'couponActid': [],
#    'describe': 'Sony PS4 Pro主機- 1TB (極致黑)',
#    'isNC17': 0,
#    'isPChome': 1,
#    'name': 'PS4 Pro -1TB (極致黑)',
#    'originPrice': 12980,
#    'picB': '/items/DGBJA7A9008KXL7/000001_1519609863.jpg',
#    'picS': '/items/DGBJA7A9008KXL7/000002_1514635363.jpg',
#    'price': 12980,
#    'publishDate': '',
#    'sellerId': ''},
#   {'Id': 'DGBJA7-A9008I9MO',
# ...

# %%
df=data['prods']

# %%
len(df)
# Out:
# 20

# %%
df
# Out:
# [{'Id': 'DGBJA7-A9008RJA1',
#   'author': '',
#   'brand': '',
#   'cateId': 'DGBJA7',
#   'couponActid': [],
#   'describe': 'PS4 Slim主機 CUH-2117AB01 系列 500G (極致黑)',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'PS4 Slim主機 500GB《極致黑》',
#   'originPrice': 9980,
#   'picB': '/items/DGBJA7A9008RJA1/000001_1519609686.jpg',
#   'picS': '/items/DGBJA7A9008RJA1/000002_1517795410.jpg',
#   'price': 9980,
#   'publishDate': '',
#   'sellerId': ''},
#  {'Id': 'DGBJA7-A9008KXL7',
#   'author': '',
#   'brand': '',
#   'cateId': 'DGBJA7',
#   'couponActid': [],
#   'describe': 'Sony PS4 Pro主機- 1TB (極致黑)',
#   'isNC17': 0,
#   'isPChome': 1,
#   'name': 'PS4 Pro -1TB (極致黑)',
#   'originPrice': 12980,
#   'picB': '/items/DGBJA7A9008KXL7/000001_1519609863.jpg',
#   'picS': '/items/DGBJA7A9008KXL7/000002_1514635363.jpg',
#   'price': 12980,
#   'publishDate': '',
#   'sellerId': ''},
#  {'Id': 'DGBJA7-A9008I9MO',
#   'author': '',
#   'brand': '',
#   'cateId': 'DGBJA7',
#   'couponActid': [],
# ...

# %%
for product in df :
    print (product['name'])
    print (product['price'])
# Out:
# PS4 Slim主機 500GB《極致黑》
# 9980
# PS4 Pro -1TB (極致黑)
# 12980
# PS4 Pro -1TB (冰河白)
# 12980
# PS4 Pro -1TB (極致黑)
# 12980
# PS4 Pro《戰神 God of War》「Limited Edition」主機同捆組
# 14480
# PS4 Pro 1TB主機
# 12980
# PS4 魔物獵人 世界 亞版中文版
# 1790
# PS4 Pro 1TB主機《雙手把組》贈：主機直立架+手把果凍套*2
# 13980
# ▉勇者鬥惡龍+Pro主機特別組合▉ 內含:PS4 Pro(1TB主機)+《勇者鬥惡龍XI 尋覓逝去的時光》中文版+特典
# 14580
# PS4《太空戰士15 Final Fantasy XV 完全版》中文版
# 1490
# PS4遊戲 人中北斗-中文版
# 1690
# PS4 無線耳機組
# 2980
# ▉Silm主機 遊戲任選超值周邊組▉ 內含:《PS4 Silm 500G 極致黑主機》+《精選遊戲》+《專用周邊》
# 10990
# ▉Silm主機 遊戲任選超值周邊組▉ 內含:《PS4 Silm 500G 極致黑主機》+《精選遊戲》+《專用周邊》
# 11480
# PS4《真 三國無雙 8》中文一般版
# 1790
# SONY PS4 無線立體聲耳機
# 2980
# PS4 REVOLUTION PRO CONTROLLER 2 專業控制器
# 3980
# PS4 Pro 1TB主機+GTA俠盜獵車手5+地平線 期待黎明《贈14天會籍+直立架》
# 14980
# PS4 DUALSHOCK 4 無線控制器 《魔物獵人:世界》火龍特別版
# 1780
# PS4 Slim主機(黑)500G+遊戲任選X1 送DOBE雙手充電底座
# 11150

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['product']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import pandas
dd = pandas.DataFrame(df)

# %%
dd
# Out:
#                   Id author brand  cateId couponActid  \
# 0   DGBJA7-A9008RJA1               DGBJA7          []
# 1   DGBJA7-A9008KXL7               DGBJA7          []
# 2   DGBJA7-A9008I9MO               DGBJA7          []
# 3   QAAS1J-A9008R6HA               QAAS1J          []
# 4   DGBJ88-A9008TYIB               DGBJ88          []
# 5   QAAS2N-A9008D18S               QAAS2N          []
# 6   DGBJ85-A9008QIRV               DGBJ85          []
# 7   QAAS2N-A9008MPF6               QAAS2N          []
# 8   DGBJA7-19008M724               DGCK27          []
# 9   DGBJ85-A9008TKRM               DGBJ85          []
# 10  DGBJ88-A9008L26E               DGBJAA          []
# 11  DGBJA8-A9008RQHH               DGBJA8          []
# 12  DGBJBD-19008SLHZ               DGBJA7          []
# 13  DGBJBD-19008SLKD               DGBJA7          []
# 14  DGBJ88-A9008J8E8               DGBJ85          []
# 15  DGBJA8-A90084NVG               DGBJA8          []
# ...
