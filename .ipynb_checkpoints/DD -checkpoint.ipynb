# %%
print ("hello")
# Out:
# hello

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
plot([1,2,3,4], [2,10,-4,15] )

# %%
plot(rand(100))

# %%
x=linspace(-10,10,7)

# %%
x
# Out:
# array([-10.        ,  -6.66666667,  -3.33333333,   0.        ,
#          3.33333333,   6.66666667,  10.        ])

# %%
for i in [3 , 6, 8]:
    print (i)
# Out:
# 3
# 6
# 8

# %%
range(5)
# Out:
# range(0, 5)

# %%
for i in range(5):
    print (i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
numbers = range(1,101)

# %%
s=0

# %%
for x in numbers:
    s = s + x

# %%
 print (s)
# Out:
# 5050

# %%
def foo(x):
    print (x)

# %%
foo("hi")
# Out:
# hi

# %%
def love(n):
    return ("love"*n)

# %%
love(5)
# Out:
# 'lovelovelovelovelove'

# %%
def f(x):
    return x**2

# %%
f(2)
# Out:
# 4

# %%
from numpy import *

# %%
arr=array([1,-3,2])

# %%
arr
# Out:
# array([ 1, -3,  2])

# %%
import numpy as np

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=randn(10)

# %%
y=randn(10)

# %%
scatter(x,y)

# %%
arr = randn(10,5)

# %%
arr
# Out:
# array([[ 0.20886473,  0.95301282,  0.18499204, -0.30020577,  0.5648929 ],
#        [-0.51683312,  0.18117422,  2.11273546,  1.86979374, -2.40583997],
#        [ 1.06578304, -0.8869348 , -0.51283055,  0.74801069, -1.81789454],
#        [-0.41299586, -0.24661714,  0.45508803, -1.85075381, -1.5684673 ],
#        [ 0.28049032, -0.3374381 , -0.67946663, -0.14411131,  0.1329893 ],
#        [-0.44095164, -1.92455592, -2.38601509, -0.1088316 , -1.20872217],
#        [-1.14451425,  0.33494697,  0.14237421,  0.36116113,  0.41008542],
#        [-1.68278344, -1.71909781, -0.40949703,  1.24438759, -1.02538924],
#        [-1.77811339,  1.51380166, -1.48046652, -0.33218261,  0.23162998],
#        [ 1.43988623,  0.51972938,  0.52995742,  0.36188445,  0.12163451]])

# %%
arr[1,2:]
# Out:
# array([ 2.11273546,  1.86979374, -2.40583997])

# %%
arr.shape=(10,10)

# %%
arr
# Out:
# array([[ 0.17779831, -0.1441495 ,  1.10347231, -0.09470923,  0.30893155,
#         -1.94955042,  1.87262331, -1.14977912, -0.82582324,  0.4514678 ],
#        [ 0.80282114,  1.37317134,  1.1261849 , -0.75133835,  0.8190222 ,
#         -1.36586117, -1.52038382, -1.60789918, -0.24279839, -1.75492863],
#        [ 1.49395461, -0.72056766, -0.01003083, -0.25429791,  0.50420279,
#         -1.14970231,  0.21081224,  1.3869328 , -0.62535473,  0.59759373],
#        [ 0.50179689, -0.15670712,  0.3676412 , -1.23282489, -1.36840863,
#          1.28895466, -1.6475647 ,  0.37364676,  0.07516307,  0.37214473],
#        [ 0.39417637,  0.91997784, -0.49215085,  0.64708089,  0.91123787,
#          0.9722328 ,  0.46226043, -1.77250025, -0.29452367,  1.06711415],
#        [-2.21486669, -0.02970649, -0.80978247, -0.60859307, -0.13125826,
#         -0.16031118,  0.36366315, -0.51510518,  0.86728407, -0.43616019],
#        [-0.53254835,  0.42499314, -1.41236212, -1.79206997, -0.84427751,
# ...

# %%
import pandas as pd

# %%
s = pd.Series(rand(10))

# %%
s
# Out:
# 0    0.682711
# 1    0.817861
# 2    0.615824
# 3    0.673995
# 4    0.409936
# 5    0.544128
# 6    0.789696
# 7    0.396235
# 8    0.847358
# 9    0.180473
# dtype: float64

# %%
s[s<0.5]
# Out:
# 4    0.409936
# 7    0.396235
# 9    0.180473
# dtype: float64

# %%
s[s<0.5]+=5

# %%
s
# Out:
# 0    0.682711
# 1    0.817861
# 2    0.615824
# 3    0.673995
# 4    5.409936
# 5    0.544128
# 6    0.789696
# 7    5.396235
# 8    0.847358
# 9    5.180473
# dtype: float64

# %%
s.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
ss=pd.Series(normal(70,10,30))

# %%
ss
# Out:
# 0     64.726806
# 1     69.456657
# 2     67.873153
# 3     61.358633
# 4     53.112633
# 5     68.234598
# 6     81.587544
# 7     85.031857
# 8     79.523926
# 9     70.542862
# 10    74.495257
# 11    69.839026
# 12    63.200148
# 13    66.884231
# 14    82.320533
# 15    70.608853
# 16    71.060419
# 17    52.108865
# 18    89.233822
# 19    66.286954
# 20    55.008031
# 21    91.793320
# 22    64.231731
# 23    52.075995
# 24    82.141376
# 25    72.509461
# 26    95.345197
# 27    61.200232
# 28    65.806403
# 29    58.738574
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
data = randn(10,5)

# %%
data
# Out:
# array([[ 0.1027231 , -0.15157098, -0.3900581 ,  0.77167983, -0.27994464],
#        [-0.36878843,  1.15507693,  0.14937035,  2.07873944,  1.09246766],
#        [ 0.11224556,  0.51920812, -1.79757157,  1.94617359, -1.06142958],
#        [ 1.47660589, -1.01347689, -1.66165451,  1.33455089, -1.08424138],
#        [-0.09928067, -0.24422451,  1.55741994, -2.11063712, -1.24823213],
#        [ 0.10431276, -0.76958518, -0.3749854 , -0.43598761,  0.49246067],
#        [ 0.71897814, -1.20593343,  0.39784885, -1.08780174, -0.52070746],
#        [-0.92702417,  0.67908522, -0.23978633, -1.47355201,  0.22783215],
#        [-0.71494856,  0.91624977,  0.40143943,  1.03935079, -0.72063391],
#        [ 0.4979618 , -0.07993251, -1.60961558,  0.12530547,  1.6933945 ]])

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.102723 -0.151571 -0.390058  0.771680 -0.279945
# 1 -0.368788  1.155077  0.149370  2.078739  1.092468
# 2  0.112246  0.519208 -1.797572  1.946174 -1.061430
# 3  1.476606 -1.013477 -1.661655  1.334551 -1.084241
# 4 -0.099281 -0.244225  1.557420 -2.110637 -1.248232
# 5  0.104313 -0.769585 -0.374985 -0.435988  0.492461
# 6  0.718978 -1.205933  0.397849 -1.087802 -0.520707
# 7 -0.927024  0.679085 -0.239786 -1.473552  0.227832
# 8 -0.714949  0.916250  0.401439  1.039351 -0.720634
# 9  0.497962 -0.079933 -1.609616  0.125305  1.693395

# %%
list("ABCDE")
# Out:
# ['A', 'B', 'C', 'D', 'E']

# %%
df=pd.DataFrame(data, columns=list("ABCDE"))

# %%
df.head()
# Out:
#           A         B         C         D         E
# 0  0.102723 -0.151571 -0.390058  0.771680 -0.279945
# 1 -0.368788  1.155077  0.149370  2.078739  1.092468
# 2  0.112246  0.519208 -1.797572  1.946174 -1.061430
# 3  1.476606 -1.013477 -1.661655  1.334551 -1.084241
# 4 -0.099281 -0.244225  1.557420 -2.110637 -1.248232

# %%
df[["A","C"]]
# Out:
#           A         C
# 0  0.102723 -0.390058
# 1 -0.368788  0.149370
# 2  0.112246 -1.797572
# 3  1.476606 -1.661655
# 4 -0.099281  1.557420
# 5  0.104313 -0.374985
# 6  0.718978  0.397849
# 7 -0.927024 -0.239786
# 8 -0.714949  0.401439
# 9  0.497962 -1.609616

# %%
df.plot()

# %%
normal(60,5,5)
# Out:
# array([ 60.65604224,  63.7273349 ,  55.73365217,  57.3179919 ,  55.96786467])

# %%
pd.date_range("2015-01-01","2015-12-31",freq="M")
# Out:
# DatetimeIndex(['2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30',
#                '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31',
#                '2015-09-30', '2015-10-31', '2015-11-30', '2015-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
date=pd.date_range("2015-01-01","2015-12-31",freq="M")

# %%
df=pd.DataFrame(normal(100,20,(12,5)),index=date,columns=list("ABCDE"))

# %%
df.head()
# Out:
#                      A           B           C           D           E
# 2015-01-31  107.292026  119.545507  110.257033   89.472166  144.782924
# 2015-02-28  105.112696   96.988633   72.362822   82.014453  108.717668
# 2015-03-31   94.913582   79.090942   89.384691   88.782649  111.799330
# 2015-04-30  112.366608   93.815254  115.843147   80.357338  106.539243
# 2015-05-31   92.292011  115.566815   85.260378  107.129564   99.903921

# %%
df.plot()

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas_datareader.data as web

# %%
import datetime

# %%
start = datetime.datetime(2017,1,1)

# %%
end = datetime.datetime(2018,1,1)

# %%
df=web.DataReader('TSLA','google',start,end)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas_datareader\google\daily.py:40: UnstableAPIWarning:
# The Google Finance API has not been stable since late 2017. Requests seem
# to fail at random. Failure is especially common when bulk downloading.
#
#   warnings.warn(UNSTABLE_WARNING, UnstableAPIWarning)

# %%
df.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-01-03  214.86  220.33  210.96  216.99   5923254
# 2017-01-04  214.75  228.00  214.31  226.99  11213471
# 2017-01-05  226.42  227.48  221.95  226.75   5911695
# 2017-01-06  226.93  230.31  225.45  229.01   5527893
# 2017-01-09  228.97  231.92  228.00  231.28   3979484

# %%
df[['Open','Close']].tail(10).plot()
